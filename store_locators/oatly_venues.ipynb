# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time
import math

import json
import requests
import gmaps
from sodapy import Socrata
import geopandas as gpd
from shapely.geometry import Polygon, LineString, Point
# from shapely.geometry.polygon import Polygon

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Greater Goods RoastingEast 5th
# 2501 E 5th St, Austin, TX 78702
# Fleet Coffee
# 2427 Webberville Rd, Austin, TX 78702
# Lou's Bodega
# 1900 E Cesar Chavez St, Austin, TX 78702
# Flat Track Coffee
# 1619 E Cesar Chavez St, Austin, TX 78702
# Royal Blue #6 E. 6th
# 1629 E 6th St, Austin, TX 78702
# Cenote
# 1010 E Cesar Chavez St, Austin, TX 78702
# Brew & Brew
# 500 San Marcos St, Austin, TX 78702
# Creature Coffee
# 807 E 4th St, Austin, TX 78702
# Royal Blue #5 On Rainey Street Caffe Medici 8c 51 Rainey St, Austin, TX 78701
# Little Brother Bar
# 89 Rainey St, Austin, TX 78701
# Alta's Cafe
# 74 Trinity St, Austin, TX 78701
# Henbit
# 111 Congress Ave, Austin, TX 78701
# The Line Hotel
# 111 E Cesar Chavez St, Austin, TX 78701
# Houndstooth (mlk)
# 2823 E Martin Luther King Jr Blvd, Austin, TX 78702
# Forthright Cafe
# 35 Brazos St, Austin, TX 78701
# Squeezery
# 612 Brazos St, Austin, TX 78701
# Caffe Medici
# 200 Congress Ave, Austin, TX 78701
# Royal Blue #3 On Congress Intelligentsia Coffee Inc
# 609 Congress Ave, Austin, TX 78701
# Caffe Medici
# 804 Congress Ave, Austin, TX 78701
# Bistro At Lark & Ow
# 205 W 6th St, Austin, TX 78701
# Royal Blue #1 On 3rd St
# 241 W 3rd St, Austin, TX 78701
# South Bites Coffee Bar
# 1400 Lavaca St, Austin, TX 78701
# Royal Blue #2 On Nueces
# 360 Nueces St, Austin, TX 78701
# Juan Pelota Cafe
# 400 Nueces St, Austin, TX 78701
# Intelligentsia Coffee Inc
# 607 W 3rd St, Austin, TX 78701
# Manana
# 1603 S Congress Ave, Austin, TX 78704
# Tiny House Coffee Roasters
# 801 Barton Springs Rd, Austin, TX 78704
# Allegro Coffee Co. - Global Coffee Mart
# 550 Bowie St, Austin, TX 78703
# Idlewild
# 812 W 12th St, Austin, TX 78701
# Caffe Medici
# 2222b Guadalupe St, Austin, TX 78705
# Caffe Medici Guadalupe
# 2222 Guadalupe St, Austin, TX 78705
# Whole Foods Market
# 525 N Lamar Blvd, Austin, TX 78703 (512) 542-2200
# 2018 Sweetish Hill Bakery Llc
# 1120 W 6th St, Austin, TX 78703
# Bouldin Creek Coffeehouse
# 1900 S 1st St, Austin, TX 78704
# Carpenter Hotel
# 400 Josephine St, Austin, TX 78704
# Caffe Medici
# 1100 S Lamar Blvd, Austin, TX 78704
# Juice Society
# 1116 S Lamar Blvd, Austin, TX 78704
# Whichcraft
# 1900 Simond Ave, Austin, TX 78723
# Caffe Medici
# 1101 W Lynn St, Austin, TX 78703
# Rebel Cheese
# 2200 Aldrich St, Austin, TX 78723
# Cosmic Coffee + Beer Garden
# 121 Pickle Rd, Austin, TX 78704
# Spokesman
# 440 E Saint Elmo Rd, Austin, TX 78745
# Natural Grocers By Vitamin Cottage
# 4615 N Lamar Blvd, Austin, TX 78751 (512) 323-5100
# Common Grounds (woodway) Cenote #2 (cameron Rd)
# 6214 Cameron Rd, Austin, TX 78723
# Radio Coffee & Beer
# 4204 Manchaca Rd, Austin, TX 78704
# Delaware North (medici Cafe')
# 3600 Presidential Blvd, Austin, TX 78719
# Dia's Market
# 812 Justin Ln, Austin, TX 78757
# Fat Cats
# 7020 Easy Wind Dr, Austin, TX 78752
# Bougie's Donuts
# 5400 Brodie Ln, Austin, TX 78745

# %% [markdown]
# Didnt include:
#  walmart
#  target
#  heb
#  7 eleve
#  randalls
#  Sprouts Farmers Market
# Wheatsville Co-op
# Fresh Plus Grocery
# Rabbit Food Grocery
# toms shoes

# %%
venues_list = ["Greater Goods RoastingEast 5th", "2501 E 5th St, Austin, TX 78702",
"Fleet Coffee",
"2427 Webberville Rd, Austin, TX 78702",
"Lou's Bodega",
"1900 E Cesar Chavez St, Austin, TX 78702",
"Flat Track Coffee",
"1619 E Cesar Chavez St, Austin, TX 78702",
"Royal Blue #6 E. 6th",
"1629 E 6th St, Austin, TX 78702",
"Cenote",
"1010 E Cesar Chavez St, Austin, TX 78702",
"Brew & Brew",
"500 San Marcos St, Austin, TX 78702",
"Creature Coffee",
"807 E 4th St, Austin, TX 78702",
"Royal Blue #5 On Rainey Street Caffe Medici 8c",
"51 Rainey St, Austin, TX 78701",
"Little Brother Bar",
"89 Rainey St, Austin, TX 78701",
"Alta's Cafe",
"74 Trinity St, Austin, TX 78701",
"Henbit",
"111 Congress Ave, Austin, TX 78701",
"The Line Hotel",
"111 E Cesar Chavez St, Austin, TX 78701",
"Houndstooth (mlk)",
"2823 E Martin Luther King Jr Blvd, Austin, TX 78702",
"Forthright Cafe",
"35 Brazos St, Austin, TX 78701",
"Squeezery",
"612 Brazos St, Austin, TX 78701",
"Caffe Medici",
"200 Congress Ave, Austin, TX 78701",
"Royal Blue #3 On Congress Intelligentsia Coffee Inc",
"609 Congress Ave, Austin, TX 78701",
"Caffe Medici",
"804 Congress Ave, Austin, TX 78701",
"Bistro At Lark & Ow",
"205 W 6th St, Austin, TX 78701",
"Royal Blue #1 On 3rd St",
"241 W 3rd St, Austin, TX 78701",
"South Bites Coffee Bar",
"1400 Lavaca St, Austin, TX 78701",
"Royal Blue #2 On Nueces",
"360 Nueces St, Austin, TX 78701",
"Juan Pelota Cafe",
"400 Nueces St, Austin, TX 78701",
"Intelligentsia Coffee Inc",
"607 W 3rd St, Austin, TX 78701",
"Manana",
"1603 S Congress Ave, Austin, TX 78704",
"Tiny House Coffee Roasters",
"801 Barton Springs Rd, Austin, TX 78704",
"Allegro Coffee Co. - Global Coffee Mart",
"550 Bowie St, Austin, TX 78703",
"Idlewild",
"812 W 12th St, Austin, TX 78701",
"Caffe Medici",
"2222b Guadalupe St, Austin, TX 78705",
"Caffe Medici Guadalupe",
"2222 Guadalupe St, Austin, TX 78705",
"Whole Foods Market",
"525 N Lamar Blvd, Austin, TX 78703",
"2018 Sweetish Hill Bakery Llc",
"1120 W 6th St, Austin, TX 78703",
"Bouldin Creek Coffeehouse",
"1900 S 1st St, Austin, TX 78704",
"Carpenter Hotel",
"400 Josephine St, Austin, TX 78704",
"Caffe Medici",
"1100 S Lamar Blvd, Austin, TX 78704",
"Juice Society",
"1116 S Lamar Blvd, Austin, TX 78704",
"Whichcraft",
"1900 Simond Ave, Austin, TX 78723",
"Caffe Medici",
"1101 W Lynn St, Austin, TX 78703",
"Rebel Cheese",
"2200 Aldrich St, Austin, TX 78723",
"Cosmic Coffee + Beer Garden",
"121 Pickle Rd, Austin, TX 78704",
"Spokesman",
"440 E Saint Elmo Rd, Austin, TX 78745",
"Natural Grocers By Vitamin Cottage",
"4615 N Lamar Blvd, Austin, TX 78751",
"Common Grounds (woodway) Cenote #2 (cameron Rd)",
"6214 Cameron Rd, Austin, TX 78723",
"Radio Coffee & Beer",
"4204 Manchaca Rd, Austin, TX 78704",
"Delaware North (medici Cafe')",
"3600 Presidential Blvd, Austin, TX 78719",
"Dia's Market",
"812 Justin Ln, Austin, TX 78757",
"Fat Cats",
"7020 Easy Wind Dr, Austin, TX 78752",
"Bougie's Donuts", "5400 Brodie Ln, Austin, TX 78745"]

# %%
venues_df = pd.DataFrame()
venues_df['venue'] = [venues_list[i] for i in range(0, len(venues_list)) if i % 2 == 0]
venues_df['address'] = [venues_list[i] for i in range(0, len(venues_list)) if i % 2 == 1]
venues_df.head()
# Out:
#                             venue                                   address
# 0  Greater Goods RoastingEast 5th           2501 E 5th St, Austin, TX 78702
# 1                    Fleet Coffee     2427 Webberville Rd, Austin, TX 78702
# 2                    Lou's Bodega  1900 E Cesar Chavez St, Austin, TX 78702
# 3               Flat Track Coffee  1619 E Cesar Chavez St, Austin, TX 78702
# 4            Royal Blue #6 E. 6th           1629 E 6th St, Austin, TX 78702

# %%
gkey='AIzaSyDQqzCSC8c-tzstYt-ODcsSho_Ac5R96Kg'
gmaps.configure(api_key=gkey)

g_coords=[]
lats = []
lons = []
for n in venues_df['address']:
    url='https://maps.googleapis.com/maps/api/geocode/json?address={}&key={}'.format(n, gkey)
    results = requests.get(url).json()
    lats.append(results['results'][0]['geometry']['location']['lat'])
    lons.append(results['results'][0]['geometry']['location']['lng'])
    
venues_df['latitude'] = lats
venues_df['longitude'] = lons

# %%
venues_df.head()
# Out:
#                             venue                                   address  \
# 0  Greater Goods RoastingEast 5th           2501 E 5th St, Austin, TX 78702
# 1                    Fleet Coffee     2427 Webberville Rd, Austin, TX 78702
# 2                    Lou's Bodega  1900 E Cesar Chavez St, Austin, TX 78702
# 3               Flat Track Coffee  1619 E Cesar Chavez St, Austin, TX 78702
# 4            Royal Blue #6 E. 6th           1629 E 6th St, Austin, TX 78702
#
#     latitude  longitude
# 0  30.257683 -97.714982
# 1  30.262761 -97.714359
# 2  30.257243 -97.724337
# 3  30.257703 -97.727179
# 4  30.262481 -97.725200

# %%
# venues_df.info()
venues_df.isnull().sum()
# Out:
# venue        0
# address      0
# latitude     0
# longitude    0
# dtype: int64

# %%
venues_df.to_csv('data/oatly_venues.csv')

# %%
# venues_df['neighborhood'] = 'Unidentified'

# for row in range(0,len(venues_df)):
#     point=Point(venues_df['longitude'][row], venues_df['latitude'][row])
#     idx = 0
#     for geom in neighborhoods_df['stripped_geom']:
#         poly = Polygon(geom)
#         if poly.contains(point):
#             serves_impossible_df['neighborhood'][row] = neighborhoods_df['neighname'][idx]
#         else:
#             pass
#         idx += 1
